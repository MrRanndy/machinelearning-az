# %% [markdown]
# <a href="https://colab.research.google.com/github/MrRanndy/machinelearning-az/blob/master/original/Part%202%20-%20Regression/Section%204%20-%20Simple%20Linear%20Regression/simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clonamos el repositorio para obtener los dataSet

# %%
# !git clone https://github.com/joanby/machinelearning-az.git
# Out:
# Cloning into 'machinelearning-az'...
# remote: Enumerating objects: 10878, done.
# remote: Counting objects: 100% (292/292), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 10878 (delta 187), reused 146 (delta 146), pack-reused 10586 (from 2)
# Receiving objects: 100% (10878/10878), 315.89 MiB | 19.23 MiB/s, done.
# Resolving deltas: 100% (326/326), done.
# Updating files: 100% (20461/20461), done.

# %% [markdown]
# # Damos acceso a nuestro Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !find /content/machinelearning-az -name "Salary_Data.csv"
# Out:
# /content/machinelearning-az/original/Part 2 - Regression/Section 4 - Simple Linear Regression/Salary_Data.csv
# /content/machinelearning-az/update/Part 2 - Regression/Section 4 - Simple Linear Regression/R/Salary_Data.csv
# /content/machinelearning-az/update/Part 2 - Regression/Section 4 - Simple Linear Regression/Python/Salary_Data.csv

# %% [markdown]
# # Test it

# %%
# !ls '/content/drive/My Drive'

# %% [markdown]
# # Google colab tools

# %%
from google.colab import files # Para manejar los archivos y, por ejemplo, exportar a su navegador
import glob # Para manejar los archivos y, por ejemplo, exportar a su navegador
from google.colab import drive # Montar tu Google drive

# %% [markdown]
# # Regresión Lineal Simple

# %% [markdown]
# # Cómo importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importar el data set

# %%
"""dataset = pd.read_csv('/content/machinelearning-az/datasets/Part 2 - Regression/Section 4 - Simple Linear Regression/Salary_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values"""

dataset = pd.read_csv("/content/machinelearning-az/update/Part 2 - Regression/Section 4 - Simple Linear Regression/Python/Salary_Data.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %% [markdown]
# # Dividir el data set en conjunto de entrenamiento y conjunto de testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
result = pd.DataFrame({'Column1': X[:, 0]})

# %% [markdown]
# # Escalado de variables

# %%
"""
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
"""

# %% [markdown]
# # Crear modelo de Regresión Lienal Simple con el conjunto de entrenamiento

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predecir el conjunto de test

# %%
y_pred = regression.predict(X_test)

# %% [markdown]
# # Visualizar los resultados de entrenamiento

# %%
plt.scatter(X_train, y_train, color = "red")
plt.plot(X_train, regression.predict(X_train), color = "blue")
plt.title("Sueldo vs Años de Experiencia (Conjunto de Entrenamiento)")
plt.xlabel("Años de Experiencia")
plt.ylabel("Sueldo (en $)")
plt.show()

# %% [markdown]
# # Visualizar los resultados de test

# %%
plt.scatter(X_test, y_test, color = "red")
plt.plot(X_train, regression.predict(X_train), color = "blue")
plt.title("Sueldo vs Años de Experiencia (Conjunto de Testing)")
plt.xlabel("Años de Experiencia")
plt.ylabel("Sueldo (en $)")
plt.show()
